# %%
import shap
import pickle

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from ydata_profiling import ProfileReport
from deepchecks.tabular import Dataset
from deepchecks.tabular.checks import FeatureDrift

from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from catboost import (
    CatBoostRegressor,
    CatBoostClassifier,
    Pool, 
    cv, 
    EShapCalcType, 
    EFeaturesSelectionAlgorithm
)


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# # Функции

# %% [markdown]
# ### Функция для расчета метрики

# %%
def weighted_mean_absolute_error(y_true, y_pred, weights):

    '''

    Weighted mean absolute error.

    Parameters
    ----------
    y_true: ndarray
        Ground truth
    y_pred: ndarray
        Array of predictions

    Returns
    -------
    rmsle: float
        Weighted mean absolute error

    References
    ----------
    .. [1] https://kaggle-metrics.readthedocs.io/en/latest/_modules/kaggle_metrics/regression.html

    '''
    
    return (weights * np.abs(y_true - y_pred)).mean()

# %% [markdown]
# ### Функция для обучения базовой модели

# %%
def fit_catboost(features_train, 
                 features_val, 
                 target_train, 
                 target_val, 
                 cat_features, 
                 n_iter=500,
                 train_weight=None,
                 val_weight=None):
    
    pool_train = Pool(
        features_train,
        target_train,
        weight = train_weight,
        cat_features = cat_features
    )

    pool_val = Pool(
        features_val,
        target_val,
        weight = val_weight,
        cat_features = cat_features
    )

    model = CatBoostRegressor(
        iterations= n_iter,
        learning_rate=0.05,
        loss_function='RMSE',
        random_seed = 42
    )

    model.fit(
        pool_train,
        eval_set=pool_val,
        verbose=100,
        plot=True
    )

    return model

# %% [markdown]
# # Чтение данных

# %%
train_df = pd.read_csv('data/train.csv', sep=";", decimal=",", encoding="windows-1251")
test_df = pd.read_csv('data/test.csv', sep=";", decimal=",", encoding="windows-1251")

features_description = (
    pd.read_excel('data/description.xlsx', index_col='field')
    .to_dict()['description']
)

train_df.shape, test_df.shape
# Out:
# ((205962, 235), (37183, 233))

# %% [markdown]
# # Предварительный анализ EDA

# %%
features = list(train_df.drop(['client_id', 'feature_date', 'target', 'w'], axis=1).columns)
train_df[features].select_dtypes('object').head()
# Out:
#                  addrref bki_total_ip_max_limit hdb_bki_active_cc_cnt  \
# 0   Свердловская область                    NaN                   2.0
# 1  Новосибирская область                    NaN                   6.0
# 2  Новосибирская область                    NaN                   4.0
# 3     Московская область                    NaN                   0.0
# 4     Краснодарский край                    NaN                   3.0
#
#   hdb_bki_active_ip_max_outstand hdb_bki_active_micro_max_outstand  \
# 0                      1006774.6                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                       646694.0                               NaN
# 4                            NaN                               NaN
#
#   hdb_bki_active_pil_max_overdue hdb_bki_other_active_auto_month_payments_sum  \
# 0                            0.0                                          NaN
# 1                            0.0                                          NaN
# 2                            0.0                                          NaN
# 3                            NaN                                          NaN
# 4                       14264.13                                          NaN
#
#   hdb_bki_total_cc_max_limit hdb_bki_total_ip_cnt hdb_bki_total_max_limit  \
# 0                   170000.0                  1.0               4250000.0
# 1                   110000.0                  0.0                183500.0
# 2                    65000.0                  0.0                558500.0
# 3                        0.0                  3.0               1780000.0
# 4                    62500.0                  0.0               1120000.0
#
#   hdb_bki_total_max_overdue_sum hdb_bki_total_pil_max_limit  \
# 0                      235937.0                    220000.0
# 1                        2527.0                    183500.0
# 2                        7678.0                    558500.0
# 3                           0.0                    427000.0
# 4                      14264.13                   1120000.0
#
#   main_last_position_ccode main_pre_last_position_ccode  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#   oldest_campaignsegment_ccode_for_nss oldest_campaignsegment_ccode_for_pil  \
# 0                                  NaN                               PIL2CC
# 1                            ACFYN_NZP                              PIL2PIL
# 2                            ACFYN_NZP                              PIL2PIL
# 3                            ACFYN_NZP                              PIL2PAY
# 4                            ACFYN_NZP                              PIL2PAY
#
#   part_last_position_ccode part_pre_last_position_ccode        segment brand  \
# 0                      NaN                          NaN  Mass Affluent   NaN
# 1                      NaN                          NaN  Mass Affluent   NaN
# 2                      NaN                          NaN  Mass Affluent   NaN
# 3                      NaN                          NaN  Mass Affluent   NaN
# 4                      NaN                          NaN           Mass   NaN
#
#   model
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %% [markdown]
# ### Поправляем типы данных для фичей

# %%
print('Количество униклаьных значений по фиче:')
for f in train_df[features].select_dtypes('object').columns:
    print(f"{f}: {train_df[f].value_counts().count()}")
# Out:
# Количество униклаьных значений по фиче:
# addrref: 59
# bki_total_ip_max_limit: 2763
# hdb_bki_active_cc_cnt: 60
# hdb_bki_active_ip_max_outstand: 43267
# hdb_bki_active_micro_max_outstand: 5458
# hdb_bki_active_pil_max_overdue: 24365
# hdb_bki_other_active_auto_month_payments_sum: 3533
# hdb_bki_total_cc_max_limit: 9991
# hdb_bki_total_ip_cnt: 15
# hdb_bki_total_max_limit: 52263
# hdb_bki_total_max_overdue_sum: 56162
# hdb_bki_total_pil_max_limit: 54202
# main_last_position_ccode: 9207
# main_pre_last_position_ccode: 5192
# oldest_campaignsegment_ccode_for_nss: 56
# oldest_campaignsegment_ccode_for_pil: 13
# part_last_position_ccode: 1236
# part_pre_last_position_ccode: 1325
# segment: 3
# brand: 422
# model: 2397

# %% [markdown]
# В соответствии с описанием фичей было выяснено, что для всех фичей, которые начинаются с 'hdb_bki' требуется выставить тип данных float

# %%
newtype_feats = [
    'bki_total_ip_max_limit',
    'hdb_bki_active_cc_cnt',
    'hdb_bki_active_ip_max_outstand',
    'hdb_bki_active_micro_max_outstand',
    'hdb_bki_active_pil_max_overdue',
    'hdb_bki_other_active_auto_month_payments_sum',
    'hdb_bki_total_cc_max_limit',
    'hdb_bki_total_ip_cnt',
    'hdb_bki_total_max_limit',
    'hdb_bki_total_max_overdue_sum',
    'hdb_bki_total_pil_max_limit'
]

test_df[newtype_feats] = test_df[newtype_feats].astype('float64')
test_df['feature_date'] = test_df['feature_date'].astype('datetime64[ns]')

train_df[newtype_feats] = train_df[newtype_feats].astype('float64')
train_df['feature_date'] = train_df['feature_date'].astype('datetime64[ns]')
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205962 entries, 0 to 205961
# Columns: 235 entries, client_id to productionyear
# dtypes: datetime64[ns](1), float64(223), int64(1), object(10)
# memory usage: 369.3+ MB

# %%
cat_features = list(train_df[features].select_dtypes('object').columns)
num_features = list(set(features) - set(cat_features))

len(features), len(cat_features), len(num_features)
# Out:
# (231, 10, 221)

# %% [markdown]
# ### Анализ категорильных фичей

# %%
# сколько всего записей, где известна должность, но не известна зп?
train_df.loc[
    (train_df['worksalary_rur_amt'].isna())
    & (~train_df['part_last_position_ccode'].isna())
].shape
# Out:
# (4184, 235)

# %%
# df, содержащий медианные зарплаты для должностей по всем данным
median_worksalary = (
    pd.concat([train_df[features], test_df[features]], axis=0)
    .dropna(subset = 'worksalary_rur_amt')
    .groupby('part_last_position_ccode', as_index=False)
    ['worksalary_rur_amt'].median()
    .rename(columns={'worksalary_rur_amt': 'median_worksalary_rur_amt'})
)
median_worksalary.head()
# Out:
#   part_last_position_ccode  median_worksalary_rur_amt
# 0              АВТОМЕХАНИК                   158892.5
# 1            АДМИНИСТРАТОР                   180000.0
# 2                 АНАЛИТИК                   100000.0
# 3            Администратор                    60000.0
# 4   Администратор магазина                    70000.0

# %%
test_df = test_df.merge(median_worksalary, on='part_last_position_ccode', how='left')
test_df['worksalary_rur_amt'] = test_df['worksalary_rur_amt'].fillna(test_df['median_worksalary_rur_amt'])
test_df.drop('median_worksalary_rur_amt', axis=1, inplace=True)

train_df = train_df.merge(median_worksalary, on='part_last_position_ccode', how='left')
train_df['worksalary_rur_amt'] = train_df['worksalary_rur_amt'].fillna(train_df['median_worksalary_rur_amt'])
train_df.drop('median_worksalary_rur_amt', axis=1, inplace=True)

train_df.loc[
    (train_df['worksalary_rur_amt'].isna())
    & (~train_df['part_last_position_ccode'].isna())
].shape
# Out:
# (1029, 235)

# %%
# заполняем пропуски в категориальных
train_df[cat_features] = train_df[cat_features].fillna('miss_value')
test_df[cat_features] = test_df[cat_features].fillna('miss_value')

# %% [markdown]
# # Инженерия фич

# %%
train_df['feature_date_year'] = train_df['feature_date'].dt.year
train_df['feature_date_month'] = train_df['feature_date'].dt.month
train_df['feature_date_day'] = train_df['feature_date'].dt.day

test_df['feature_date_year'] = test_df['feature_date'].dt.year
test_df['feature_date_month'] = test_df['feature_date'].dt.month
test_df['feature_date_day'] = test_df['feature_date'].dt.day

# %% [markdown]
# ### Получаем предсказания модели, которая предсказывает сегмент доходности клиента (model_clf)

# %%
clf_model = CatBoostClassifier()
clf_model.load_model('models/3cl_6_9_model_clf')

with open('models/3cl_6_9_label_encoder.pkl', 'rb') as f:
    le = pickle.load(f)

train_df['target_bins'] = None
train_df.loc[train_df['target'] <= train_df['target'].quantile(0.333), 'target_bins'] = 'bin_0'
train_df.loc[
    (train_df['target'] > train_df['target'].quantile(0.333))
    & (train_df['target'] <= train_df['target'].quantile(0.666)), 
    'target_bins'
] = 'bin_1'
train_df.loc[train_df['target'] > train_df['target'].quantile(0.666), 'target_bins'] = 'bin_2'

train_df['target_bins'] = le.transform(train_df['target_bins'])

# train_df['target_bins'] = clf_model.predict(train_df[clf_model.feature_names_])[:,-1]
# train_df['cl0_prob'] = clf_model.predict_proba(train_df[clf_model.feature_names_])[:,0]
# train_df['cl1_prob'] = clf_model.predict_proba(train_df[clf_model.feature_names_])[:,1]
# train_df['cl2_prob'] = clf_model.predict_proba(train_df[clf_model.feature_names_])[:,2]

test_df['target_bins'] = clf_model.predict(test_df[clf_model.feature_names_])[:,-1]
# test_df['cl0_prob'] = clf_model.predict_proba(test_df[clf_model.feature_names_])[:,0]
# test_df['cl1_prob'] = clf_model.predict_proba(test_df[clf_model.feature_names_])[:,1]
# test_df['cl2_prob'] = clf_model.predict_proba(test_df[clf_model.feature_names_])[:,2]
test_df.head()
# Out:
#    client_id feature_date  accum_rur_amt_cm_avg_div_v2  \
# 0     208030   2023-09-30                     0.073655
# 1     208031   2023-09-30                     1.000000
# 2     208032   2023-09-30                     0.937650
# 3     208033   2023-09-30                     1.000000
# 4     208034   2023-09-30                     1.000000
#
#                             addrref  \
# 0             Нижегородская область
# 1                 Красноярский край
# 2                         г. Москва
# 3  Республика Татарстан (Татарстан)
# 4                  Хабаровский край
#
#    amount_by_category_30d__summarur_amt__sum__cashflowcategory_name__bilety_na_kontserty_i_v_teatry  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_30d__summarur_amt__sum__cashflowcategory_name__brokerskie_uslugi  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_30d__summarur_amt__sum__cashflowcategory_name__hosting  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_30d__summarur_amt__sum__cashflowcategory_name__spa_sauny_bani  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_30d__summarur_amt__sum__cashflowcategory_name__tovary_dlja_detej  \
# 0                                                NaN
# 1                                                NaN
# 2                                             3841.3
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_30d__summarur_amt__sum__cashflowcategory_name__turisticheskie_agenstva  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_90d__summarur_amt__sum__cashflowcategory_name__marketplejsy  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_90d__summarur_amt__sum__cashflowcategory_name__nalogi  \
# 0                                             4000.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_90d__summarur_amt__sum__cashflowcategory_name__ohota_i_rybalka  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    amount_by_category_90d__summarur_amt__sum__cashflowcategory_name__prochie_bilety  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    atravel  avg_3m_hotels  avg_6m_building_services  \
# 0      0.0         4218.0                    1453.0
# 1      0.0            0.0                    1600.0
# 2      0.0         9128.0                    2004.0
# 3      0.0            0.0                       0.0
# 4      1.0            0.0                   79575.0
#
#    avg_6m_money_transactions  avg_6m_personal_services  avg_6m_transportation  \
# 0                  1368123.0                     685.0                15837.0
# 1                    64100.0                    1550.0                 3864.0
# 2                     2900.0                    1468.0                 2991.0
# 3                     6417.0                       0.0                    0.0
# 4                   270000.0                    5200.0                 7808.0
#
#    avg_by_category__amount__sum__cashflowcategory_name__detskie_igrushki  \
# 0                                         172.438356
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avg_by_category__amount__sum__cashflowcategory_name__investitsii  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avg_by_category__amount__sum__cashflowcategory_name__odezhda_dlja_beremennyh  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avg_by_category__amount__sum__cashflowcategory_name__vydacha_nalichnyh_v_bankomate  \
# 0                                      469602.739726
# 1                                       52619.178082
# 2                                        1430.136986
# 3                                        3164.383562
# 4                                      234000.000000
#
#    avg_by_category__amount__sum__cashflowcategory_name__zdorove  \
# 0                                         522.739726
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                        3873.616438
#
#    avg_by_category__amount__sum__cashflowcategory_name__zooparki  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    avg_cnt_daily_transactions_90d  avg_debet_turn_rur  avg_percents_inc  \
# 0                        6.222222           7303452.0            2962.0
# 1                        1.633333             99002.0               0.0
# 2                        4.211111            379534.0               0.0
# 3                        0.022222             37510.0               0.0
# 4                        1.444444           1027102.0               0.0
#
#    bki_total_ip_max_limit  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#    by_category__amount__sum__eoperation_type_name__perevod_mezhdu_svoimi_schetami  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    by_category__amount__sum__eoperation_type_name__platezh_cherez_vidzhet_moj_mobilnyj  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    by_category__amount__sum__eoperation_type_name__pokupka_paja  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    by_category__amount__sum__eoperation_type_name__vneshnij_perevod_rur  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                       11919.812055
#
#    calls_weight_v2  card_dda_rur_amt_cm_avg_div_v2  \
# 0              0.7                             1.0
# 1              NaN                             1.0
# 2              NaN                             1.0
# 3              NaN                             1.0
# 4              NaN                             1.0
#
#    cc_other_rate_max_2avg_prop  \
# 0                        0.945
# 1                        1.024
# 2                        0.945
# 3                        1.024
# 4                        0.880
#
#    channel_agentskij_kanal_voc_features_12m_avg_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_agentskij_kanal_voc_features_12m_cnt_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_bankomaty_voc_features_36m_avg_mark  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    channel_bankomaty_voc_features_36m_voc_without_marks_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_bankomaty_voc_features_3m_mark_eq_5_flag  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    channel_bankomaty_voc_features_full_mark_eq_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_bankomaty_voc_features_full_voc_not_null_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chat_s_operatorom_alfainvestitsii_voc_features_12m_avg_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chat_s_operatorom_alfainvestitsii_voc_features_36m_mark_not_null_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chat_s_operatorom_voc_features_12m_cnt_mark  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    channel_chat_s_operatorom_voc_features_12m_mark_eq_3_flag  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    channel_chat_s_operatorom_voc_features_12m_voc_with_expert_cnt  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    channel_chat_s_operatorom_voc_features_3m_mark_eq_4_flag  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    channel_chat_s_operatorom_voc_features_full_voc_without_marks_portion  \
# 0                                                1.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#    channel_chatbot_alfainvestitsii_voc_features_12m_mark_in_4_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_alfainvestitsii_voc_features_12m_voc_with_expert_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_alfainvestitsii_voc_features_36m_mark_eq_3_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_alfainvestitsii_voc_features_36m_min_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_alfainvestitsii_voc_features_3m_mark_eq_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_alfainvestitsii_voc_features_3m_mark_in_4_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_alfainvestitsii_voc_features_full_avg_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_voc_features_12m_mark_in_1_3_flag  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    channel_chatbot_voc_features_12m_voc_with_expert_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_chatbot_voc_features_full_voc_without_marks_portion  \
# 0                                                1.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    channel_collection_voc_features_36m_cnt_mark  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    channel_collection_voc_features_36m_mark_eq_2_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_collection_voc_features_36m_voc_not_null_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_collection_voc_features_3m_voc_with_expert_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_collection_voc_features_full_voc_without_marks_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_finansovyj_sovetnik_voc_features_36m_avg_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_finansovyj_sovetnik_voc_features_3m_voc_with_expert_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_finansovyj_sovetnik_voc_features_full_avg_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_finansovyj_sovetnik_voc_features_full_voc_with_expert_cnt  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_frodmonitoring_voc_features_12m_mark_eq_2_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_frodmonitoring_voc_features_12m_max_mark  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    channel_frodmonitoring_voc_features_3m_mark_in_4_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_frodmonitoring_voc_features_3m_voc_without_marks_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_frodmonitoring_voc_features_full_voc_not_null_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_glid_voc_features_12m_mark_eq_3_flag  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    channel_glid_voc_features_12m_mark_in_1_3_flag  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    channel_glid_voc_features_36m_mark_in_4_5_flag  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    channel_glid_voc_features_3m_mark_eq_1_flag  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    channel_ivr_voc_features_36m_voc_not_null_flag  \
# 0                                             1.0
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    channel_ivr_voc_features_3m_mark_eq_5_flag  \
# 0                                         0.0
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    channel_ivr_voc_features_full_mark_eq_3_flag  \
# 0                                           0.0
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    channel_kts_alfainvestitsii_voc_features_12m_mark_eq_1_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_kts_alfainvestitsii_voc_features_full_mark_eq_4_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_mobilnoe_prilozhenie_ai_voc_features_36m_mark_in_4_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_mobilnoe_prilozhenie_ai_voc_features_36m_voc_with_expert_cnt  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_mobilnoe_prilozhenie_ai_voc_features_full_mark_eq_2_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_mobilnoe_prilozhenie_am_voc_features_12m_mark_eq_1_flag  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    channel_mobilnoe_prilozhenie_am_voc_features_12m_voc_with_expert_cnt  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    channel_mobilnoe_prilozhenie_am_voc_features_3m_max_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_otdelenija_voc_features_full_mark_eq_1_flag  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    channel_otdelenija_voc_features_full_mark_eq_4_flag  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    channel_otdelenija_voc_features_full_voc_not_null_flag  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                1.0
# 4                                                1.0
#
#    channel_predstavitelstvo_voc_features_12m_mark_eq_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_predstavitelstvo_voc_features_36m_min_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_predstavitelstvo_voc_features_36m_voc_without_marks_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_predstavitelstvo_voc_features_3m_voc_not_null_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_pretenzii_voc_features_36m_mark_in_1_3_flag  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_pretenzii_voc_features_3m_mark_in_4_5_flag  \
# 0                                                0.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    channel_pretenzii_voc_features_full_avg_mark  ...  \
# 0                                           5.0  ...
# 1                                           NaN  ...
# 2                                           NaN  ...
# 3                                           NaN  ...
# 4                                           NaN  ...
#
#    min_clip_max_ul_actoff_90_30_inc  min_max_limit  \
# 0                               NaN       180000.0
# 1                               NaN       180000.0
# 2                               NaN       180000.0
# 3                               NaN       180000.0
# 4                               NaN      1300000.0
#
#    min_pil_max_score_actoff_180d  min_pil_max_ul_actoff_90d  mob_cnt_days  \
# 0                          263.0                      556.0          69.0
# 1                            NaN                        NaN           NaN
# 2                          234.0                      638.0          46.0
# 3                            NaN                        NaN          18.0
# 4                            NaN                        NaN          57.0
#
#    mob_cover_days  mortgage_main_3  mortgage_main_90  \
# 0        0.766667              NaN               NaN
# 1             NaN              NaN               NaN
# 2        0.511111              NaN               NaN
# 3        0.200000              NaN               NaN
# 4        0.633333              NaN               NaN
#
#    oldest_campaignsegment_ccode_for_nss  oldest_campaignsegment_ccode_for_pil  \
# 0                            miss_value                                PIL2CC
# 1                             ACFYN_NZP                                PIL2CC
# 2                            NS_ALFA_CL                               PIL2PAY
# 3                            miss_value                                PIL2CC
# 4                             ACFYN_PUM                            miss_value
#
#    part_last_position_ccode  part_pre_last_position_ccode  \
# 0                miss_value                    miss_value
# 1                miss_value                    miss_value
# 2                miss_value                    miss_value
# 3                miss_value                    miss_value
# 4                miss_value                    miss_value
#
#    percent_outcome_rur_amt  prod_anketa_cc_7  prod_anketa_pil_refin_30  \
# 0              -126.496916               NaN                       NaN
# 1                -4.790927               NaN                       NaN
# 2              -753.503214               NaN                       NaN
# 3                -1.819565               NaN                       NaN
# 4              -221.132604               NaN                       NaN
#
#    prod_page_pil_90  prod_page_pil_clicks_90  prod_page_sa_30  \
# 0               NaN                      NaN              NaN
# 1               NaN                      NaN              NaN
# 2               NaN                      NaN              NaN
# 3               NaN                      NaN              NaN
# 4               NaN                      NaN              NaN
#
#    prod_page_travel_30  product_auto_loan_ratio_hy  \
# 0                  NaN                         NaN
# 1                  NaN                         NaN
# 2                  NaN                         NaN
# 3                  NaN                         NaN
# 4                  NaN                         NaN
#
#    product_brokerskoe_obsluzhivanie_voc_features_12m_cnt_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_brokerskoe_obsluzhivanie_voc_features_36m_mark_eq_2_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_brokerskoe_obsluzhivanie_voc_features_36m_voc_with_expert_cnt  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_brokerskoe_obsluzhivanie_voc_features_3m_mark_eq_3_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_brokerskoe_obsluzhivanie_voc_features_3m_min_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_debetovye_karty_voc_features_36m_mark_in_1_3_flag  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_debetovye_karty_voc_features_36m_min_mark  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_debetovye_karty_voc_features_36m_voc_not_null_flag  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_debetovye_karty_voc_features_full_mark_eq_2_flag  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   product_debetovye_karty_voc_features_full_mark_not_null_flag  \
# 0                                                1.0
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   product_debetovye_karty_voc_features_full_min_mark  \
# 0                                                5.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_debetovye_karty_voc_features_full_voc_with_expert_cnt  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_depozity_voc_features_full_voc_without_marks_portion  \
# 0                                                1.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_ipoteka_voc_features_12m_mark_eq_5_flag  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    product_ipoteka_voc_features_36m_mark_eq_1_flag  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    product_ipoteka_voc_features_3m_mark_in_4_5_flag  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    product_ipoteka_voc_features_3m_mark_not_null_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_ipoteka_voc_features_full_mark_eq_3_flag  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    product_kreditnye_karty_voc_features_12m_avg_mark  \
# 0                                                5.0
# 1                                                5.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_kreditnye_karty_voc_features_36m_mark_eq_5_flag  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    product_kreditnye_karty_voc_features_36m_min_mark  \
# 0                                                5.0
# 1                                                5.0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_kreditnye_karty_voc_features_36m_voc_with_expert_cnt  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    product_kreditnye_karty_voc_features_3m_mark_eq_1_flag  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    product_kreditnye_karty_voc_features_full_mark_not_null_flag  \
# 0                                                1.0
# 1                                                1.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    product_nakopitelnye_scheta_voc_features_36m_mark_not_null_flag  \
# 0                                                1.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   product_other_comm_cur_status_hy product_other_depos_ratio_hy  \
# 0                              NaN                          0.0
# 1                              NaN                          0.0
# 2                              NaN                          NaN
# 3                              NaN                          0.0
# 4                              NaN                          0.0
#
#   product_zarplatnaja_karta_voc_features_36m_mark_eq_5_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#   product_zarplatnaja_karta_voc_features_36m_voc_without_marks_portion  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#    product_zarplatnaja_karta_voc_features_3m_voc_with_expert_cnt  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                0.0
#
#    product_zarplatnyj_proekt_voc_features_12m_mark_eq_3_flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_zarplatnyj_proekt_voc_features_36m_avg_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_zarplatnyj_proekt_voc_features_36m_cnt_mark  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    product_zarplatnyj_proekt_voc_features_3m_mark_in_1_3_flag  prof_cc_prof  \
# 0                                                NaN              -7.004611
# 1                                                NaN               0.000000
# 2                                                NaN               0.000000
# 3                                                NaN            -264.549864
# 4                                                NaN               0.000000
#
#    profit_income_out_rur_amt_9m  puupg_offer_exists_pass_180d        segment  \
# 0                  40045.888889                           0.0       Affluent
# 1                    633.333333                           0.0  Mass Affluent
# 2                   1403.333333                           1.0           Mass
# 3                   -263.444444                           0.0           Mass
# 4                   3187.777778                           0.0       Affluent
#
#    smsInWavg6m  staff_flag  first_salary_income  sum_rare_countries  \
# 0     673.0842         0.0                  NaN                 NaN
# 1     144.1376         0.0                  NaN                 NaN
# 2     196.3226         0.0                  NaN                 NaN
# 3     119.1420         0.0                  NaN                 NaN
# 4          NaN         0.0                  NaN           1088.3648
#
#    summarur_1m_miscellaneous_stores  summarur_1m_no_cat  \
# 0                             100.0               810.0
# 1                           12272.0                 0.0
# 2                               0.0                 0.0
# 3                               0.0                 0.0
# 4                               0.0                 0.0
#
#    top_channel_weight_v2  total_rur_amt_cm_avg_div_v2  \
# 0                  4.785                     0.218077
# 1                    NaN                     2.669697
# 2                    NaN                     0.368320
# 3                    NaN                     0.373250
# 4                    NaN                     0.659985
#
#    total_rur_amt_cm_avg_period_days_ago_v2  \
# 0                                 810756.0
# 1                                   6379.0
# 2                                 367015.0
# 3                                   4000.0
# 4                                 837069.0
#
#    transaction_category_airplane_tickets_sum_cnt_d15  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    transaction_category_clothers_shoes_sum_amt_d15  \
# 0                                              NaN
# 1                                          32980.0
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    transaction_category_general_store_inc_amt_15d  \
# 0                                             NaN
# 1                                        0.761234
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    transaction_category_general_store_inc_cnt_2m  \
# 0                                            NaN
# 1                                       1.474747
# 2                                       4.055556
# 3                                            NaN
# 4                                       1.303571
#
#    transaction_category_hotels_sum_amt_d15  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    transaction_category_hotels_sum_amt_m2  \
# 0                                 12652.5
# 1                                     NaN
# 2                                 16485.0
# 3                                     NaN
# 4                                     NaN
#
#    transaction_category_house_repair_inc_cnt_2m  \
# 0                                           NaN
# 1                                      3.041667
# 2                                      3.041667
# 3                                           NaN
# 4                                      0.493243
#
#    transaction_category_money_send_inc_amt_15d  \
# 0                                     1.027296
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    transaction_category_money_send_sum_cnt_m2  \
# 0                                        83.0
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         2.0
#
#    transaction_category_other_retail_purchase_percent_amt_2m  \
# 0                                           0.004629
# 1                                                NaN
# 2                                           0.030862
# 3                                                NaN
# 4                                           0.232399
#
#    transaction_category_supermarket_sum_amt_m3_4  \
# 0                                       68794.07
# 1                                       13891.51
# 2                                       84748.73
# 3                                            NaN
# 4                                       53657.56
#
#    transaction_category_supermarket_sum_cnt_d15  \
# 0                                           7.0
# 1                                          16.0
# 2                                          16.0
# 3                                           NaN
# 4                                           1.0
#
#    transaction_category_train_tickets_percent_amt_2m  turn_cc_cr_max_v2  \
# 0                                           0.004556         1283340.00
# 1                                                NaN           49712.53
# 2                                                NaN                NaN
# 3                                                NaN           35000.00
# 4                                                NaN                NaN
#
#    turn_cc_db_min_v2  turn_cc_db_sum_v2  turn_other_cr_avg_v2  \
# 0         7665419.36         7665419.36         934896.384167
# 1          294282.40          294282.40          34940.200000
# 2                NaN                NaN          15534.502500
# 3          220596.69          220596.69          44768.115000
# 4                NaN                NaN         100208.333333
#
#    turn_other_db_max_v2     uniV5  unique_countries1  \
# 0            1877900.00  0.010395                NaN
# 1              75000.00  0.034858                NaN
# 2               2307.35  0.016814                NaN
# 3             172000.00  0.027220                NaN
# 4             525000.00  0.009274                NaN
#
#    vcu_other_rate_max_2avg_prop  voc_features_12m_voc_without_marks_portion  \
# 0                           NaN                                    0.761905
# 1                           NaN                                    1.000000
# 2                           NaN                                    0.700000
# 3                           NaN                                    0.818182
# 4                           NaN                                    0.900000
#
#    voc_features_36m_mark_eq_1_flag  voc_features_36m_max_mark  \
# 0                              0.0                        5.0
# 1                              0.0                        5.0
# 2                              1.0                        5.0
# 3                              0.0                        5.0
# 4                              0.0                        5.0
#
#    voc_features_full_mark_eq_3_flag  worksalary_rur_amt       brand  \
# 0                               1.0                 NaN  miss_value
# 1                               0.0                 NaN  miss_value
# 2                               0.0                 NaN  miss_value
# 3                               1.0                 NaN  miss_value
# 4                               0.0                 NaN  miss_value
#
#         model  productionyear  feature_date_year  feature_date_month  \
# 0  miss_value             NaN               2023                   9
# 1  miss_value             NaN               2023                   9
# 2  miss_value             NaN               2023                   9
# 3  miss_value             NaN               2023                   9
# 4  miss_value             NaN               2023                   9
#
#    feature_date_day  target_bins
# 0                30            1
# 1                30            0
# 2                30            2
# 3                30            0
# 4                30            2
#
# [5 rows x 237 columns]

# %%
features = list(train_df.drop(['client_id', 'feature_date', 'target', 'w', 'target_bins'], axis=1).columns)

cat_features = list(train_df[features].select_dtypes('object').columns)
num_features = list(set(features) - set(cat_features))

len(features), len(cat_features), len(num_features)
# Out:
# (234, 10, 224)

# %% [markdown]
# # Обучение модели

# %%
features_train, features_val, target_train, target_val = train_test_split(
    train_df[features],
    train_df['target'],
    test_size=0.3,
    random_state=42
)

w_train, w_val, bins_train, bins_val = train_test_split(
    train_df['w'],
    train_df['target_bins'],
    test_size=0.3,
    random_state=42
)

# %% [markdown]
# ## Обучение модели на всех фичах с фичами от классификатора

# %%
model = fit_catboost(
    features_train,
    features_val,
    target_train, 
    target_val, 
    cat_features, 
    400
)

WMAE = weighted_mean_absolute_error(target_val, model.predict(features_val), w_val)
print(f"WMAE = {WMAE:.2f}")
print(f"Overfit: {model.evals_result_['validation']['RMSE'][-1] - model.evals_result_['learn']['RMSE'][-1]}")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 86722.6308951	test: 86912.3300717	best: 86912.3300717 (0)	total: 286ms	remaining: 1m 54s
# 100:	learn: 61242.8780421	test: 61709.5908836	best: 61709.5908836 (100)	total: 15.2s	remaining: 45s
# 200:	learn: 59115.7138071	test: 60096.3026703	best: 60096.3026703 (200)	total: 29.7s	remaining: 29.4s
# 300:	learn: 57726.3478420	test: 59275.5505979	best: 59275.5505979 (300)	total: 44.7s	remaining: 14.7s
# 399:	learn: 56677.4814554	test: 58826.0811459	best: 58826.0811459 (399)	total: 59.7s	remaining: 0us
#
# bestTest = 58826.08115
# bestIteration = 399
#
# WMAE = 31898.49
# Overfit: 2148.5996905507855

# %%
# Plot Residuals
residuals = target_val - model.predict(features_val)
plt.scatter(target_val, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
shap_values = (
    shap
    .TreeExplainer(model)
    .shap_values(features_val)
)
shap.summary_plot(shap_values, features_val)
# Out:
# d:\ml\income-prediction-alfa-campus\.venv\Lib\site-packages\shap\plots\_beeswarm.py:960: UserWarning:
#
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
shap_importance = (
    pd.DataFrame(
        {"feature":  features_train.columns, "importance": np.mean(np.abs(shap_values), axis=0)}
    ).sort_values("importance", ascending=False, ignore_index=True)
)
shap_importance.head()
# Out:
#                       feature    importance
# 0          avg_debet_turn_rur  10111.974925
# 1                     segment   9074.746053
# 2  hdb_bki_total_cc_max_limit   5493.343297
# 3          feature_date_month   5215.822156
# 4         curr_rur_amt_cm_avg   5130.274346

# %% [markdown]
# ## Отбор фич (факторный анализ)

# %%
# по пропущенным значениям

def feats_filter_nan(df: pd.DataFrame,
                     num_feat: list,
                     cat_feat: list,
                     nan_threshold: float):

    """Функция отбора фичей по доле NaN-значений.
    Фичи, которые имеют долю NaN-значений не ниже заданного nan_threshold, подлежат удалению.

    Parameters
    ----------
    df : pd.DataFrame
        датафрейм с фичами
    num_feat : list
        список числовых фичей
    cat_feat : list
        список категориальных фичей (в нашем случае для них NaN-значением является 'miss_value')
    nan_threshold : float
        порог удаления фичи

    Returns
    -------
    list
        список фичей, которые останутся в датафрейме

    """

    # для числовых фичей
    nan_stats_num = (
        df[num_feat]
        .isna().mean(axis=0)
        .reset_index()
        .rename(columns={0: 'nan_frac', 'index': 'col'})
    )
    # для категориальных
    nan_stats_cat = (
        (df[cat_feat] == 'miss_value')
        .mean(axis=0)
        .reset_index()
        .rename(columns={0: 'nan_frac', 'index': 'col'})
    )

    nan_stats = pd.concat([nan_stats_num, nan_stats_cat])
    selected_features = list(nan_stats[nan_stats['nan_frac'] < nan_threshold]['col'])

    return selected_features


deleted_features = list(set(features) - set(feats_filter_nan(train_df, num_features, cat_features, 0.95)))
display(shap_importance.loc[shap_importance.feature.isin(deleted_features)].head(10))

selected_features = feats_filter_nan(train_df, num_features, cat_features, 0.95)
selected_features_num = [feat for feat in num_features if feat in selected_features]
selected_features_cat = [feat for feat in cat_features if feat in selected_features]
len(selected_features)
# Out:
#                                                feature  importance
# 44                                 first_salary_income  348.561684
# 49        hdb_bki_other_active_auto_month_payments_sum  316.440625
# 57   product_depozity_voc_features_full_voc_without...  233.349275
# 61                                               brand  193.972550
# 76   avg_by_category__amount__sum__cashflowcategory...   63.993651
# 86                                   unique_countries1   33.707667
# 98                  min_cc_max_pilot_score_actoff_180d   13.196693
# 101       channel_pretenzii_voc_features_full_avg_mark   12.769329
# 106            transaction_category_hotels_sum_amt_d15    6.225631
# 110  transaction_category_airplane_tickets_sum_cnt_d15    3.268402
# 146

# %% [markdown]
# Отброшены потенцильно хорошие фичи. Вернем их в список фичей

# %%
selected_features += list(
    shap_importance.loc[shap_importance.feature.isin(deleted_features), 'feature'].values[:4]
)
selected_features_num = [feat for feat in num_features if feat in selected_features]
selected_features_cat = [feat for feat in cat_features if feat in selected_features]
len(selected_features)
# Out:
# 150

# %%
# по доле самого частого значения

def feats_filter_nunique(df: pd.DataFrame,
                         features: list,
                         unique_threshold: float):

    """Функция отбора фичей по доле самого частого значения.
    Фичи, которые имеют 1 уникальное значение (помимо NaN), либо для которых
      доля самого частого значения (включая NaN) не ниже unique_threshold, подлежат удалению.

    Parameters
    ----------
    df : pd.DataFrame
        датафрейм с фичами
    features : list
        список фичей
    unique_threshold : float
        порог удаления фичи

    Returns
    -------
    list
        список фичей, которые останутся в датафрейме

    """

    selected_features = []

    for feat in features:
        if df[feat].nunique() >= 2 and df[feat].astype(str).value_counts(1).values[0] < unique_threshold:
            selected_features += [feat]

    return selected_features

deleted_features = list(set(selected_features) - set(feats_filter_nunique(train_df, selected_features, 0.95)))
display(shap_importance.loc[shap_importance.feature.isin(deleted_features)].head(10))

selected_features = feats_filter_nunique(train_df, selected_features, 0.95)
selected_features_num = [feat for feat in num_features if feat in selected_features]
selected_features_cat = [feat for feat in cat_features if feat in selected_features]
len(selected_features)
# Out:
#                                                feature  importance
# 44                                 first_salary_income  348.561684
# 49        hdb_bki_other_active_auto_month_payments_sum  316.440625
# 57   product_depozity_voc_features_full_voc_without...  233.349275
# 61                                               brand  193.972550
# 88   channel_bankomaty_voc_features_full_voc_not_nu...   29.555108
# 202                           loan_on_realty_clicks_90    0.000000
# 221  channel_otdelenija_voc_features_full_voc_not_n...    0.000000
# 143

# %%
selected_features += list(
    shap_importance.loc[shap_importance.feature.isin(deleted_features), 'feature'].values[:4]
)
selected_features_num = [feat for feat in num_features if feat in selected_features]
selected_features_cat = [feat for feat in cat_features if feat in selected_features]
len(selected_features)
# Out:
# 147

# %%
# отсечение по рандомной фиче

def feats_filter_random_feat(df: pd.DataFrame,
                             features: list,
                             cat_features: list):

    """Функция отбора фичей при помощи отсечения менее важных фичей чем рандомная фича.
    Фичи, которые имеют в простой модели важность ниже рандомной фичи, подлежат удалению.

    Parameters
    ----------
    df : pd.DataFrame
        датафрейм с фичами
    features : list
        список фичей
    cat_features : list
        список категориальных фичей

    Returns
    -------
    list
        список фичей, которые останутся в датафрейме

    """

    df['random'] = np.random.uniform(0, 1, df.shape[0])

    pool_train = Pool(
        df[features + ['random']],
        df['target'],
        cat_features = cat_features
    )

    simple_model = CatBoostRegressor(
        iterations=400,
        learning_rate=0.05,
        loss_function='RMSE',
        random_seed = 42
    )

    simple_model.fit(
        pool_train,
        verbose=100
    )

    shap_values = (
        shap
        .TreeExplainer(simple_model)
        .shap_values(df[features + ['random']])
    )

    model_importance = (
        pd.DataFrame(
            {"feature":  features + ['random'], "importance": np.mean(np.abs(shap_values), axis=0)}
        ).sort_values("importance", ascending=False, ignore_index=True)
    )

    selected_features = list(
        model_importance[
            model_importance['importance'] 
            > model_importance.loc[model_importance['feature'] == 'random', 'importance'].values[0]
        ]['feature']
    )

    return selected_features


_selected_features = feats_filter_random_feat(train_df, selected_features, selected_features_cat)
deleted_features = list(set(selected_features) - set(_selected_features))
display(shap_importance.loc[shap_importance.feature.isin(deleted_features)].head(10))

selected_features = _selected_features
selected_features_num = [feat for feat in num_features if feat in selected_features]
selected_features_cat = [feat for feat in cat_features if feat in selected_features]
len(selected_features)
# Out:
# 0:	learn: 86775.4705477	total: 159ms	remaining: 1m 3s
# 100:	learn: 61363.7656418	total: 14.3s	remaining: 42.4s
# 200:	learn: 59226.5179909	total: 28.9s	remaining: 28.6s
# 300:	learn: 57955.9105297	total: 42.3s	remaining: 13.9s
# 399:	learn: 56949.5826313	total: 55.8s	remaining: 0us
#                                                feature  importance
# 63   product_debetovye_karty_voc_features_36m_voc_n...  169.753356
# 65   channel_chatbot_voc_features_12m_mark_in_1_3_flag  160.335868
# 68                               hdb_bki_active_cc_cnt  138.852550
# 78   product_kreditnye_karty_voc_features_3m_mark_e...   54.553290
# 90      channel_ivr_voc_features_36m_voc_not_null_flag   26.749485
# 95   flg_clip_cc_presence_in_previous_30_days_with_...   20.798995
# 99                                 prod_page_travel_30   13.072665
# 103     transaction_category_general_store_inc_amt_15d    8.815636
# 104  amount_by_category_90d__summarur_amt__sum__cas...    7.067393
# 105  avg_by_category__amount__sum__cashflowcategory...    7.041187
# 101

# %%
# selected_features += list(
#     shap_importance.loc[shap_importance.feature.isin(deleted_features), 'feature'].values[:10]
# )
# selected_features_num = [feat for feat in num_features if feat in selected_features]
# selected_features_cat = [feat for feat in cat_features if feat in selected_features]
# len(selected_features)

# %% [markdown]
# ## Обучение модели на фичах после факторного анализа

# %%
model = fit_catboost(
    features_train[selected_features], 
    features_val[selected_features], 
    target_train, 
    target_val, 
    selected_features_cat, 
    400
)

WMAE = weighted_mean_absolute_error(target_val, model.predict(features_val[selected_features]), w_val)
print(f"WMAE = {WMAE:.2f}")
print(f"Overfit: {model.evals_result_['validation']['RMSE'][-1] - model.evals_result_['learn']['RMSE'][-1]}")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 86771.7547271	test: 86972.3004436	best: 86972.3004436 (0)	total: 143ms	remaining: 57.2s
# 100:	learn: 61221.1430335	test: 61682.4629048	best: 61682.4629048 (100)	total: 11.4s	remaining: 33.6s
# 200:	learn: 59068.3282563	test: 60046.8867480	best: 60046.8867480 (200)	total: 22.3s	remaining: 22.1s
# 300:	learn: 57625.8530553	test: 59194.5079051	best: 59194.5079051 (300)	total: 33.4s	remaining: 11s
# 399:	learn: 56505.5185801	test: 58731.0095358	best: 58731.0095358 (399)	total: 44.6s	remaining: 0us
#
# bestTest = 58731.00954
# bestIteration = 399
#
# WMAE = 31804.75
# Overfit: 2225.490955652931

# %%
# Plot Residuals
residuals = target_val - model.predict(features_val[selected_features])
plt.scatter(target_val, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# ## Обучение моделей на каждый бин на выбранных фичах

# %%
# модель на нулевом бине
bin0_model = fit_catboost(
    features_train.loc[bins_train == 0, selected_features], 
    features_val.loc[bins_val == 0, selected_features], 
    target_train.loc[bins_train == 0], 
    target_val.loc[bins_val == 0], 
    selected_features_cat, 
    400
)

WMAE = weighted_mean_absolute_error(
    target_val.loc[bins_val == 0], 
    bin0_model.predict(features_val.loc[bins_val == 0, selected_features]), 
    w_val
)
print(f"WMAE = {WMAE:.2f}")
print(f"Overfit: {bin0_model.evals_result_['validation']['RMSE'][-1] - bin0_model.evals_result_['learn']['RMSE'][-1]}")

# модель на первом бине
bin1_model = fit_catboost(
    features_train.loc[bins_train == 1, selected_features], 
    features_val.loc[bins_val == 1, selected_features], 
    target_train.loc[bins_train == 1], 
    target_val.loc[bins_val == 1], 
    selected_features_cat, 
    400
)

WMAE = weighted_mean_absolute_error(
    target_val.loc[bins_val == 1], 
    bin1_model.predict(features_val.loc[bins_val == 1, selected_features]), 
    w_val
)
print(f"WMAE = {WMAE:.2f}")
print(f"Overfit: {bin1_model.evals_result_['validation']['RMSE'][-1] - bin1_model.evals_result_['learn']['RMSE'][-1]}")

# модель на втором бине
bin2_model = fit_catboost(
    features_train.loc[bins_train == 2, selected_features], 
    features_val.loc[bins_val == 2, selected_features], 
    target_train.loc[bins_train == 2], 
    target_val.loc[bins_val == 2], 
    selected_features_cat, 
    400
)

pred = pd.DataFrame(np.nan, index=target_val.index, columns = ['pred'])
pred.loc[bins_val == 0, 'pred'] = bin0_model.predict(features_val.loc[bins_val == 0, selected_features])
pred.loc[bins_val == 1, 'pred'] = bin1_model.predict(features_val.loc[bins_val == 1, selected_features])
pred.loc[bins_val == 2, 'pred'] = bin2_model.predict(features_val.loc[bins_val == 2, selected_features])

WMAE = weighted_mean_absolute_error(
    target_val, 
    pred['pred'], 
    w_val
)
print(f"WMAE = {WMAE:.2f}")
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 16074.3560077	test: 16077.6603175	best: 16077.6603175 (0)	total: 98.2ms	remaining: 39.2s
# 100:	learn: 12483.4274232	test: 12539.8104700	best: 12539.8104700 (100)	total: 8.11s	remaining: 24s
# 200:	learn: 12215.0054946	test: 12312.7897299	best: 12312.7897299 (200)	total: 16s	remaining: 15.9s
# 300:	learn: 12036.9897542	test: 12188.1968598	best: 12188.1968598 (300)	total: 24.2s	remaining: 7.97s
# 399:	learn: 11906.3434886	test: 12116.6954085	best: 12116.6954085 (399)	total: 31.9s	remaining: 0us
#
# bestTest = 12116.69541
# bestIteration = 399
#
# WMAE = 4228.65
# Overfit: 210.35191988202132
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 26867.2081236	test: 26853.6925061	best: 26853.6925061 (0)	total: 61.9ms	remaining: 24.7s
# 100:	learn: 23091.7036512	test: 23280.5430584	best: 23280.5430584 (100)	total: 6.42s	remaining: 19s
# 200:	learn: 22532.8940168	test: 22901.6262967	best: 22901.6262967 (200)	total: 12.4s	remaining: 12.3s
# 300:	learn: 22097.6567128	test: 22669.6065421	best: 22669.6065421 (300)	total: 18.5s	remaining: 6.1s
# 399:	learn: 21773.8607330	test: 22559.9534114	best: 22559.9534114 (399)	total: 24.6s	remaining: 0us
#
# bestTest = 22559.95341
# bestIteration = 399
#
# WMAE = 6889.00
# Overfit: 786.0926783321738
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 128221.2012702	test: 128064.5464238	best: 128064.5464238 (0)	total: 39.4ms	remaining: 15.7s
# 100:	learn: 107921.5270162	test: 110260.8864780	best: 110260.8864780 (100)	total: 4.5s	remaining: 13.3s
# 200:	learn: 104010.6190236	test: 108805.0881942	best: 108805.0881942 (200)	total: 8.63s	remaining: 8.55s
# 300:	learn: 100401.1157526	test: 107958.1810450	best: 107958.1810450 (300)	total: 13s	remaining: 4.26s
# 399:	learn: 97395.9198982	test: 107662.0097235	best: 107662.0097235 (399)	total: 17.3s	remaining: 0us
#
# bestTest = 107662.0097
# bestIteration = 399
#
# WMAE = 19633.89

# %%
# Plot Residuals
residuals = target_val - pred['pred']
plt.scatter(target_val, residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %% [markdown]
# ### Вывод:
# Модели на первух двух бинах имеют низкую ошибку, в отличие от модели на последнем бине. Следовательно модель плохо обучается на клиентах с высокой зарплатой. Возможно стоит выделить 2 группы клиентов: с нормальным и с экстримально высоким доходом и обучить классификатор разделять их.

# %% [markdown]
# # Инференс

# %%
bin0_pool_train = Pool(
    train_df.loc[train_df['target_bins'] == 0, selected_features],
    train_df.loc[train_df['target_bins'] == 0, 'target'],
    cat_features = selected_features_cat
)

bin0_model = CatBoostRegressor(
    iterations=400,
    learning_rate=0.05,
    loss_function='RMSE'
)

bin0_model.fit(
    bin0_pool_train,
    verbose=100,
    plot=True
)

bin1_pool_train = Pool(
    train_df.loc[train_df['target_bins'] == 1, selected_features],
    train_df.loc[train_df['target_bins'] == 1, 'target'],
    cat_features = selected_features_cat
)

bin1_model = CatBoostRegressor(
    iterations=300,
    learning_rate=0.05,
    loss_function='RMSE'
)

bin1_model.fit(
    bin1_pool_train,
    verbose=100,
    plot=True
)

bin2_pool_train = Pool(
    train_df.loc[train_df['target_bins'] == 2, selected_features],
    train_df.loc[train_df['target_bins'] == 2, 'target'],
    cat_features = selected_features_cat
)

bin2_model = CatBoostRegressor(
    iterations=250,
    learning_rate=0.05,
    loss_function='RMSE'
)

bin2_model.fit(
    bin2_pool_train,
    verbose=100,
    plot=True
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 16076.5104784	total: 132ms	remaining: 52.7s
# 100:	learn: 12488.4811429	total: 9.73s	remaining: 28.8s
# 200:	learn: 12241.1500171	total: 18.9s	remaining: 18.7s
# 300:	learn: 12068.8276343	total: 28.8s	remaining: 9.46s
# 399:	learn: 11951.1471570	total: 37.9s	remaining: 0us
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 26877.7153666	total: 61.7ms	remaining: 18.4s
# 100:	learn: 23133.2964089	total: 6.46s	remaining: 12.7s
# 200:	learn: 22605.9329458	total: 12.8s	remaining: 6.33s
# 299:	learn: 22212.7167677	total: 19.7s	remaining: 0us
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 128136.6629031	total: 43ms	remaining: 10.7s
# 100:	learn: 108147.9961981	total: 4.66s	remaining: 6.88s
# 200:	learn: 105061.9155354	total: 9s	remaining: 2.19s
# 249:	learn: 103588.3332902	total: 11.2s	remaining: 0us

# %% [markdown]
# # Commit

# %%
test_df['predict'] = None
test_df.loc[test_df['target_bins'] == 0, 'predict'] = bin0_model.predict(test_df.loc[test_df['target_bins'] == 0, selected_features])
test_df.loc[test_df['target_bins'] == 1, 'predict'] = bin1_model.predict(test_df.loc[test_df['target_bins'] == 1, selected_features])
test_df.loc[test_df['target_bins'] == 2, 'predict'] = bin2_model.predict(test_df.loc[test_df['target_bins'] == 2, selected_features])
test_df[['client_id','predict']].set_index('client_id').to_csv("data/clf_6_9_reg3.csv", sep=",", decimal=".")
